# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthamp-04/Data-Analytics/blob/main/Indian_Election_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

import re
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')

# %%
trump = pd.read_csv("hashtag_donaldtrump.csv", nrows=100)
trump
# Out:
#              created_at      tweet_id  \
# 0   2020-10-15 00:00:01  1.316529e+18
# 1   2020-10-15 00:00:01  1.316529e+18
# 2   2020-10-15 00:00:02  1.316529e+18
# 3   2020-10-15 00:00:02  1.316529e+18
# 4   2020-10-15 00:00:08  1.316529e+18
# ..                  ...           ...
# 95  2020-10-15 00:05:07  1.316531e+18
# 96  2020-10-15 00:05:08  1.316531e+18
# 97  2020-10-15 00:05:18  1.316531e+18
# 98  2020-10-15 00:05:19  1.316531e+18
# 99  2020-10-15 00:05:21  1.316531e+18
#
#                                                 tweet  likes  retweet_count  \
# 0   #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1   Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2   #Trump: As a student I used to hear for years,...    2.0            1.0
# 3   2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4   You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
# ...

# %%
trump .columns
# Out:
# Index(['created_at', 'tweet_id', 'tweet', 'likes', 'retweet_count', 'source',
#        'user_id', 'user_name', 'user_screen_name', 'user_description',
#        'user_join_date', 'user_followers_count', 'user_location', 'lat',
#        'long', 'city', 'country', 'continent', 'state', 'state_code',
#        'collected_at'],
#       dtype='object')

# %%
biden = pd.read_csv("hashtag_joebiden.csv", nrows=100)
biden
# Out:
#              created_at      tweet_id  \
# 0   2020-10-15 00:00:01  1.316529e+18
# 1   2020-10-15 00:00:18  1.316529e+18
# 2   2020-10-15 00:00:20  1.316529e+18
# 3   2020-10-15 00:00:21  1.316529e+18
# 4   2020-10-15 00:00:22  1.316529e+18
# ..                  ...           ...
# 95  2020-10-15 00:06:17  1.316531e+18
# 96  2020-10-15 00:06:17  1.316531e+18
# 97  2020-10-15 00:06:23  1.316531e+18
# 98  2020-10-15 00:06:30  1.316531e+18
# 99  2020-10-15 00:06:40  1.316531e+18
#
#                                                 tweet  likes  retweet_count  \
# 0   #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1   #HunterBiden #HunterBidenEmails #JoeBiden #Joe...    0.0            0.0
# 2   @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0            0.0
# 3   @chrislongview Watching and setting dvr. Let’s...    0.0            0.0
# 4   #censorship #HunterBiden #Biden #BidenEmails #...    1.0            0.0
# ...

# %%
trump.shape
# Out:
# (100, 21)

# %%
biden.shape
# Out:
# (100, 21)

# %%
trump.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   created_at            100 non-null    object
#  1   tweet_id              100 non-null    float64
#  2   tweet                 100 non-null    object
#  3   likes                 100 non-null    float64
#  4   retweet_count         100 non-null    float64
#  5   source                99 non-null     object
#  6   user_id               100 non-null    float64
#  7   user_name             100 non-null    object
#  8   user_screen_name      100 non-null    object
#  9   user_description      87 non-null     object
#  10  user_join_date        100 non-null    object
#  11  user_followers_count  100 non-null    float64
#  12  user_location         69 non-null     object
#  13  lat                   55 non-null     float64
#  14  long                  55 non-null     float64
# ...

# %%
biden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   created_at            100 non-null    object
#  1   tweet_id              100 non-null    float64
#  2   tweet                 100 non-null    object
#  3   likes                 100 non-null    float64
#  4   retweet_count         100 non-null    float64
#  5   source                99 non-null     object
#  6   user_id               100 non-null    float64
#  7   user_name             100 non-null    object
#  8   user_screen_name      100 non-null    object
#  9   user_description      76 non-null     object
#  10  user_join_date        100 non-null    object
#  11  user_followers_count  100 non-null    float64
#  12  user_location         51 non-null     object
#  13  lat                   42 non-null     float64
#  14  long                  42 non-null     float64
# ...

# %%
trump['candidate'] = 'trump'
biden['candidate']='biden'

# %%
data=pd.concat([trump,biden])

# %%
data.shape
# Out:
# (200, 22)

# %%
data.head(3)
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
#
#              source      user_id           user_name user_screen_name  \
# 0         TweetDeck  360666534.0  El Sol Latino News  elsollatinonews
# 1  Social Mediaset   331617619.0             Tgcom24  MediasetTgcom24
# 2   Twitter Web App    8436472.0              snarke           snarke
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#              created_at      tweet_id  \
# 2   2020-10-15 00:00:02  1.316529e+18
# 4   2020-10-15 00:00:08  1.316529e+18
# 11  2020-10-15 00:00:25  1.316529e+18
# 12  2020-10-15 00:00:26  1.316529e+18
# 13  2020-10-15 00:00:31  1.316529e+18
# 16  2020-10-15 00:00:42  1.316529e+18
# 22  2020-10-15 00:01:14  1.316530e+18
# 27  2020-10-15 00:01:23  1.316530e+18
# 29  2020-10-15 00:01:30  1.316530e+18
# 36  2020-10-15 00:01:44  1.316530e+18
# 42  2020-10-15 00:01:53  1.316530e+18
# 43  2020-10-15 00:01:53  1.316530e+18
# 45  2020-10-15 00:02:05  1.316530e+18
# 48  2020-10-15 00:02:14  1.316530e+18
# 52  2020-10-15 00:02:35  1.316530e+18
# 57  2020-10-15 00:02:55  1.316530e+18
# 62  2020-10-15 00:03:04  1.316530e+18
# 64  2020-10-15 00:03:10  1.316530e+18
# 72  2020-10-15 00:03:32  1.316530e+18
# 74  2020-10-15 00:03:38  1.316530e+18
# 75  2020-10-15 00:03:38  1.316530e+18
# 91  2020-10-15 00:04:56  1.316530e+18
# 99  2020-10-15 00:05:21  1.316531e+18
# ...

# %%
data['country'].value_counts()
# Out:
# country
# United States of America    30
# United Kingdom               4
# The Netherlands              2
# Poland                       1
# Name: count, dtype: int64

# %%
data['country'] = data['country'].replace({'United States of America': "US", 'United States': "US"})

# %%
data['country'].value_counts()
# Out:
# country
# US                 30
# United Kingdom      4
# The Netherlands     2
# Poland              1
# Name: count, dtype: int64

# %%
tweets_count = data.groupby('candidate')['tweet'].count().reset_index()

# %%
tweets_count
# Out:
#   candidate  tweet
# 0     biden     14
# 1     trump     23

# %%
fig = px.bar(tweets_count, x='candidate', y='tweet', color='candidate',
             color_discrete_map={'Trump': 'pink', 'Biden': 'blue'},
             labels={'candidate': 'Candidates', 'tweet': 'Number of Tweets'},
             title='Tweets for Candidates')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
likes_comparison = data.groupby('candidate')['likes'].sum().reset_index()

# %%
fig = px.bar(likes_comparison, x='candidate', y='likes', color='candidate',
             color_discrete_map={'Trump': 'blue', 'Biden': 'green'},
             labels={'candidate': 'Candidate', 'likes': 'Total Likes'},
             title='Comparison of Likes')

fig.update_layout(plot_bgcolor='black',
                  paper_bgcolor='black', font_color='white')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top10countries = data.groupby('country')['tweet'].count().sort_values(ascending=False).reset_index().head(10)

# %%
fig = px.bar(top10countries, x='country', y='tweet',
             template='plotly_dark',
             color_discrete_sequence=px.colors.qualitative.Dark24_r,
             title='Top10 Countrywise tweets Counts')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
tweet_df = data.groupby(['country', 'candidate'])['tweet'].count().reset_index()
tweeters = tweet_df[tweet_df['country'].isin(top10countries.country)]

# %%
fig = px.bar(tweeters, x='country', y='tweet', color='candidate',
             labels={'country': 'Country', 'tweet': 'Number of Tweets',
                     'candidate': 'Candidate'},
             title='Tweet Counts for Each Candidate in the Top 10 Countries',
             template='plotly_dark',
             barmode='group')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
